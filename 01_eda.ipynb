# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
# Age               918 non-null int64
# Sex               918 non-null object
# ChestPainType     918 non-null object
# RestingBP         918 non-null int64
# Cholesterol       918 non-null int64
# FastingBS         918 non-null int64
# RestingECG        918 non-null object
# MaxHR             918 non-null int64
# ExerciseAngina    918 non-null object
# Oldpeak           918 non-null float64
# ST_Slope          918 non-null object
# HeartDisease      918 non-null int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.pairplot(data=df, hue='HeartDisease', height=6)
# Out:
# /home/marek/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/marek/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
columns = ['Age',
           'RestingBP', 
           'Cholesterol', 
#            'FastingBS', 
           'MaxHR', 
           'Oldpeak', 
#            'HeartDisease'
          ]

sns.pairplot(data=df, 
             x_vars=columns,
             y_vars=columns,
             hue='HeartDisease', 
             height=6)

# %%
sns.FacetGrid(df, hue='HeartDisease', height=5).map(sns.distplot, 'Age', bins=30).add_legend()

# %%
sns.FacetGrid(df, hue='ChestPainType', height=5).map(sns.distplot, 'MaxHR').add_legend()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
# Age               918 non-null int64
# Sex               918 non-null object
# ChestPainType     918 non-null object
# RestingBP         918 non-null int64
# Cholesterol       918 non-null int64
# FastingBS         918 non-null int64
# RestingECG        918 non-null object
# MaxHR             918 non-null int64
# ExerciseAngina    918 non-null object
# Oldpeak           918 non-null float64
# ST_Slope          918 non-null object
# HeartDisease      918 non-null int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
sns.FacetGrid(df, 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='RestingECG', 
              height=3, aspect=2,
             sharey=False).map(sns.distplot, 'Age').add_legend()

# %%
sns.FacetGrid(df, 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='RestingECG', 
              height=3, aspect=2,
             sharey=False).map(sns.distplot, 'MaxHR').add_legend()

# %%
sns.FacetGrid(df, 
              hue='HeartDisease', 
              row='FastingBS', 
              col='RestingECG', 
              height=3, aspect=2,
             sharey=False).map(sns.distplot, 'MaxHR').add_legend()

# %%
sns.FacetGrid(df, 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='RestingECG', 
              height=3, 
              aspect=2,
              sharex=False,
              sharey=False,
             ).map(sns.distplot, 'Cholesterol').add_legend()

# %%
sns.FacetGrid(df[df.Cholesterol>0], 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='RestingECG', 
              height=3, 
              aspect=2,
              sharex=False,
              sharey=False,
             ).map(sns.distplot, 'Cholesterol').add_legend()

# %%
sns.FacetGrid(df[df.Cholesterol>0], 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='ST_Slope', 
              height=3, 
              aspect=2,
              sharex=False,
              sharey=False,
             ).map(sns.distplot, 'Cholesterol').add_legend()
# Out:
# /home/marek/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/marek/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
sns.FacetGrid(df[df.Cholesterol>0], 
              hue='HeartDisease', 
              row='ChestPainType', 
              col='ST_Slope', 
              height=3, 
              aspect=2,
              sharex=False,
              sharey=False,
             ).map(sns.distplot, 'MaxHR').add_legend()

# %%
df.groupby('ST_Slope').count().unstack()
# Out:
#                 ST_Slope
# Age             Down         63
#                 Flat        460
#                 Up          395
# Sex             Down         63
#                 Flat        460
#                 Up          395
# ChestPainType   Down         63
#                 Flat        460
#                 Up          395
# RestingBP       Down         63
#                 Flat        460
#                 Up          395
# Cholesterol     Down         63
#                 Flat        460
#                 Up          395
# FastingBS       Down         63
#                 Flat        460
#                 Up          395
# RestingECG      Down         63
#                 Flat        460
#                 Up          395
# MaxHR           Down         63
#                 Flat        460
#                 Up          395
# ExerciseAngina  Down         63
#                 Flat        460
#                 Up          395
# Oldpeak         Down         63
# ...

# %%
df.groupby('ChestPainType').count().unstack()
# Out:
#                 ChestPainType
# Age             ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# Sex             ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# RestingBP       ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# Cholesterol     ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# FastingBS       ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# RestingECG      ASY              496
#                 ATA              173
#                 NAP              203
#                 TA                46
# ...

# %%
df.groupby(['ChestPainType', 'HeartDisease']).HeartDisease.count()
# Out:
# ChestPainType  HeartDisease
# ASY            0               104
#                1               392
# ATA            0               149
#                1                24
# NAP            0               131
#                1                72
# TA             0                26
#                1                20
# Name: HeartDisease, dtype: int64

# %%
df.groupby(['ChestPainType', 'HeartDisease']).HeartDisease.count().unstack()
# Out:
# HeartDisease     0    1
# ChestPainType
# ASY            104  392
# ATA            149   24
# NAP            131   72
# TA              26   20

# %%
df.groupby(['ChestPainType', 'Sex', 'HeartDisease']).HeartDisease.count().unstack()
# Out:
# HeartDisease        0    1
# ChestPainType Sex
# ASY           F    31   39
#               M    73  353
# ATA           F    56    4
#               M    93   20
# NAP           F    47    6
#               M    84   66
# TA            F     9    1
#               M    17   19

# %%
df.groupby(['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).HeartDisease.count().unstack()
# Out:
# RestingECG                       LVH  Normal    ST
# ChestPainType Sex HeartDisease
# ASY           F   0             10.0    16.0   5.0
#                   1             12.0    22.0   5.0
#               M   0             11.0    44.0  18.0
#                   1             69.0   202.0  82.0
# ATA           F   0              7.0    40.0   9.0
#                   1              2.0     2.0   NaN
#               M   0              9.0    72.0  12.0
#                   1              5.0     9.0   6.0
# NAP           F   0             15.0    27.0   5.0
#                   1              NaN     4.0   2.0
#               M   0             19.0    57.0   8.0
#                   1             13.0    35.0  18.0
# TA            F   0              1.0     6.0   2.0
#                   1              NaN     1.0   NaN
#               M   0             10.0     5.0   2.0
#                   1              5.0    10.0   4.0

# %%
df.groupby(['ChestPainType', 'Sex', 'HeartDisease', 'ST_Slope']).HeartDisease.count().unstack()
# Out:
# ST_Slope                        Down   Flat    Up
# ChestPainType Sex HeartDisease
# ASY           F   0              NaN   14.0  17.0
#                   1              5.0   30.0   4.0
#               M   0              4.0   15.0  54.0
#                   1             37.0  259.0  57.0
# ATA           F   0              NaN    8.0  48.0
#                   1              NaN    3.0   1.0
#               M   0              2.0    6.0  85.0
#                   1              1.0   15.0   4.0
# NAP           F   0              1.0   13.0  33.0
#                   1              NaN    5.0   1.0
#               M   0              4.0   16.0  64.0
#                   1              5.0   54.0   7.0
# TA            F   0              1.0    1.0   7.0
#                   1              NaN    1.0   NaN
#               M   0              2.0    6.0   9.0
#                   1              1.0   14.0   4.0

# %%
df.groupby(['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).Age.mean().unstack()
# Out:
# RestingECG                            LVH     Normal         ST
# ChestPainType Sex HeartDisease
# ASY           F   0             51.700000  53.187500  49.400000
#                   1             58.916667  54.136364  57.000000
#               M   0             54.454545  51.340909  53.777778
#                   1             57.043478  53.737624  59.085366
# ATA           F   0             54.285714  48.725000  46.333333
#                   1             57.500000  57.000000        NaN
#               M   0             46.333333  47.527778  49.250000
#                   1             58.600000  50.222222  61.500000
# NAP           F   0             57.600000  50.185185  52.400000
#                   1                   NaN  52.000000  63.500000
#               M   0             54.052632  48.087719  54.750000
#                   1             60.769231  56.457143  57.444444
# TA            F   0             58.000000  59.500000  32.500000
# ...

# %%
df.groupby(['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).Cholesterol.mean().unstack()
# Out:
# RestingECG                             LVH      Normal          ST
# ChestPainType Sex HeartDisease
# ASY           F   0             269.900000  238.250000  257.200000
#                   1             293.916667  178.954545  240.600000
#               M   0             252.545455  218.477273  189.222222
#                   1             224.869565  160.029703  152.109756
# ATA           F   0             276.142857  236.925000  258.222222
#                   1             277.500000  336.000000         NaN
#               M   0             232.222222  232.416667  180.000000
#                   1             266.800000  204.444444  199.666667
# NAP           F   0             288.666667  236.962963  203.200000
#                   1                    NaN  244.750000  147.000000
#               M   0             228.368421  209.666667  122.875000
#                   1             163.538462  153.371429  127.555556
# TA            F   0             283.000000  238.166667  198.500000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).Cholesterol.mean().unstack()
# Out:
# RestingECG                             LVH      Normal          ST
# ChestPainType Sex HeartDisease
# ASY           F   0             269.900000  238.250000  257.200000
#                   1             293.916667  262.466667  300.750000
#               M   0             252.545455  240.325000  243.285714
#                   1             246.285714  248.661538  249.460000
# ATA           F   0             276.142857  243.000000  258.222222
#                   1             277.500000  336.000000         NaN
#               M   0             232.222222  235.690141  216.000000
#                   1             266.800000  262.857143  239.600000
# NAP           F   0             288.666667  236.962963  203.200000
#                   1                    NaN  244.750000  294.000000
#               M   0             241.055556  225.490566  196.600000
#                   1             212.600000  255.619048  229.600000
# TA            F   0             283.000000  238.166667  198.500000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).Cholesterol.agg('mean').unstack()
# Out:
# RestingECG                             LVH      Normal          ST
# ChestPainType Sex HeartDisease
# ASY           F   0             269.900000  238.250000  257.200000
#                   1             293.916667  262.466667  300.750000
#               M   0             252.545455  240.325000  243.285714
#                   1             246.285714  248.661538  249.460000
# ATA           F   0             276.142857  243.000000  258.222222
#                   1             277.500000  336.000000         NaN
#               M   0             232.222222  235.690141  216.000000
#                   1             266.800000  262.857143  239.600000
# NAP           F   0             288.666667  236.962963  203.200000
#                   1                    NaN  244.750000  294.000000
#               M   0             241.055556  225.490566  196.600000
#                   1             212.600000  255.619048  229.600000
# TA            F   0             283.000000  238.166667  198.500000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 'Sex', 'HeartDisease', 'RestingECG']).Cholesterol.describe().unstack()
# Out:
#                                count                     mean              \
# RestingECG                       LVH Normal    ST         LVH      Normal
# ChestPainType Sex HeartDisease
# ASY           F   0             10.0   16.0   5.0  269.900000  238.250000
#                   1             12.0   15.0   4.0  293.916667  262.466667
#               M   0             11.0   40.0  14.0  252.545455  240.325000
#                   1             63.0  130.0  50.0  246.285714  248.661538
# ATA           F   0              7.0   39.0   9.0  276.142857  243.000000
#                   1              2.0    2.0   NaN  277.500000  336.000000
#               M   0              9.0   71.0  10.0  232.222222  235.690141
#                   1              5.0    7.0   5.0  266.800000  262.857143
# NAP           F   0             15.0   27.0   5.0  288.666667  236.962963
#                   1              NaN    4.0   1.0         NaN  244.750000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 
     'Sex', 
     'HeartDisease', 
     'RestingECG']).Cholesterol.agg(['count', 'mean', 'min', 'max']).unstack()
# Out:
#                                count                     mean              \
# RestingECG                       LVH Normal    ST         LVH      Normal
# ChestPainType Sex HeartDisease
# ASY           F   0             10.0   16.0   5.0  269.900000  238.250000
#                   1             12.0   15.0   4.0  293.916667  262.466667
#               M   0             11.0   40.0  14.0  252.545455  240.325000
#                   1             63.0  130.0  50.0  246.285714  248.661538
# ATA           F   0              7.0   39.0   9.0  276.142857  243.000000
#                   1              2.0    2.0   NaN  277.500000  336.000000
#               M   0              9.0   71.0  10.0  232.222222  235.690141
#                   1              5.0    7.0   5.0  266.800000  262.857143
# NAP           F   0             15.0   27.0   5.0  288.666667  236.962963
#                   1              NaN    4.0   1.0         NaN  244.750000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 
     'Sex', 
     'HeartDisease', 
     'RestingECG']).Cholesterol.agg('mean').sort_values(ascending=False)
# Out:
# ChestPainType  Sex  HeartDisease  RestingECG
# ATA            F    1             Normal        336.000000
# ASY            F    1             ST            300.750000
# NAP            F    1             ST            294.000000
# ASY            F    1             LVH           293.916667
# NAP            F    0             LVH           288.666667
# TA             F    0             LVH           283.000000
#                M    1             LVH           281.000000
# ATA            F    1             LVH           277.500000
#                     0             LVH           276.142857
# ASY            F    0             LVH           269.900000
# ATA            M    1             LVH           266.800000
#                                   Normal        262.857143
# ASY            F    1             Normal        262.466667
# ATA            F    0             ST            258.222222
# ASY            F    0             ST            257.200000
# ...

# %%
df[df.Cholesterol>0].groupby(
    ['ChestPainType', 
     'Sex', 
     'HeartDisease', 
     'RestingECG']).MaxHR.agg(['mean', 'count']).sort_values(by='mean', ascending=False)
# Out:
#                                                  mean  count
# ChestPainType Sex HeartDisease RestingECG
# TA            F   0            ST          177.500000      2
# ATA           M   0            LVH         172.333333      9
#               F   1            LVH         163.000000      2
# TA            F   0            LVH         162.000000      1
# ATA           F   0            LVH         155.857143      7
#                                ST          155.777778      9
# TA            M   0            Normal      155.600000      5
#                                LVH         155.400000     10
# NAP           M   0            Normal      153.226415     53
# TA            M   1            LVH         152.666667      3
# ATA           F   0            Normal      152.128205     39
#               M   0            Normal      151.647887     71
# NAP           F   0            Normal      151.407407     27
#                                LVH         151.200000     15
# ...
